# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 5GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/odi-cricket-matches-19712017/ContinousDataset.csv
# /kaggle/input/odi-cricket-matches-19712017/CategoricalDataset.csv
# /kaggle/input/odi-cricket-matches-19712017/originalDataset.csv
# /kaggle/input/odi-cricket-matches-19712017/LabelledDataset.csv

# %%
df = pd.read_csv('../input/odi-cricket-matches-19712017/originalDataset.csv')
df.head()
# Out:
#   Scorecard       Team 1     Team 2       Winner     Margin        Ground  \
# 0   ODI # 1    Australia    England    Australia  5 wickets     Melbourne
# 1   ODI # 2      England  Australia      England  6 wickets    Manchester
# 2   ODI # 3      England  Australia    Australia  5 wickets        Lord's
# 3   ODI # 4      England  Australia      England  2 wickets    Birmingham
# 4   ODI # 5  New Zealand   Pakistan  New Zealand    22 runs  Christchurch
#
#      Match Date
# 0   Jan 5, 1971
# 1  Aug 24, 1972
# 2  Aug 26, 1972
# 3  Aug 28, 1972
# 4  Feb 11, 1973

# %%
df.tail()
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#            Ground    Match Date
# 3927       Mumbai  Oct 22, 2017
# 3928  East London  Oct 22, 2017
# 3929      Sharjah  Oct 23, 2017
# 3930         Pune  Oct 25, 2017
# 3931       Kanpur  Oct 29, 2017

# %%
df['Winner'].value_counts().keys()[0] # Most number of wins by a team from 1971 to 2017
# Out:
# 'Australia'

# %%
df
# Out:
#        Scorecard        Team 1       Team 2        Winner     Margin  \
# 0        ODI # 1     Australia      England     Australia  5 wickets
# 1        ODI # 2       England    Australia       England  6 wickets
# 2        ODI # 3       England    Australia     Australia  5 wickets
# 3        ODI # 4       England    Australia       England  2 wickets
# 4        ODI # 5   New Zealand     Pakistan   New Zealand    22 runs
# ...          ...           ...          ...           ...        ...
# 3927  ODI # 3928         India  New Zealand   New Zealand  6 wickets
# 3928  ODI # 3929  South Africa   Bangladesh  South Africa   200 runs
# 3929  ODI # 3930      Pakistan    Sri Lanka      Pakistan  9 wickets
# 3930  ODI # 3931         India  New Zealand         India  6 wickets
# 3931  ODI # 3932         India  New Zealand         India     6 runs
#
#             Ground    Match Date
# 0        Melbourne   Jan 5, 1971
# 1       Manchester  Aug 24, 1972
# 2           Lord's  Aug 26, 1972
# 3       Birmingham  Aug 28, 1972
# 4     Christchurch  Feb 11, 1973
# ...            ...           ...
# 3927        Mumbai  Oct 22, 2017
# 3928   East London  Oct 22, 2017
# 3929       Sharjah  Oct 23, 2017
# 3930          Pune  Oct 25, 2017
# 3931        Kanpur  Oct 29, 2017
#
# [3932 rows x 7 columns]

# %%
df_india_australia = df[(df['Team 1'].str.contains('Australia') | df['Team 1'].str.contains('India'))  & (df['Team 2'].str.contains('India') | df['Team 2'].str.contains('Australia'))]

# %%
df_india_australia
# Out:
#        Scorecard     Team 1     Team 2     Winner     Margin     Ground  \
# 96      ODI # 97  Australia      India      India    66 runs  Melbourne
# 99     ODI # 100  Australia      India  Australia  9 wickets     Sydney
# 103    ODI # 104  Australia      India  Australia  9 wickets     Sydney
# 105    ODI # 106  Australia      India  Australia  7 wickets  Melbourne
# 107    ODI # 108  Australia      India  Australia    27 runs     Sydney
# ...          ...        ...        ...        ...        ...        ...
# 3909  ODI # 3910      India  Australia      India    26 runs    Chennai
# 3911  ODI # 3912      India  Australia      India    50 runs    Kolkata
# 3913  ODI # 3914      India  Australia      India  5 wickets     Indore
# 3916  ODI # 3917      India  Australia  Australia    21 runs  Bengaluru
# 3918  ODI # 3919      India  Australia      India  7 wickets     Nagpur
#
#         Match Date
# 96     Dec 6, 1980
# 99    Dec 18, 1980
# 103    Jan 8, 1981
# 105   Jan 11, 1981
# 107   Jan 15, 1981
# ...            ...
# 3909  Sep 17, 2017
# 3911  Sep 21, 2017
# 3913  Sep 24, 2017
# 3916  Sep 28, 2017
# 3918   Oct 1, 2017
#
# [128 rows x 7 columns]

# %%
df_india_australia['Winner'].value_counts()
# Out:
# 380

# %%
df_in_aus_matches_played_in_pune = df2[df2['Ground'] == 'Pune']
df_in_aus_matches_played_in_pune
# Out:
#        Scorecard Team 1     Team 2     Winner     Margin Ground    Match Date
# 1697  ODI # 1698  India  Australia  Australia  8 wickets   Pune  Mar 28, 2001
# 3418  ODI # 3419  India  Australia  Australia    72 runs   Pune  Oct 13, 2013

# %%
df_most_number_of_matches_played_at_a_ground = df2['Ground'].value_counts()
df_most_number_of_matches_played_at_a_ground.keys()[0]
# Out:
# 'Sydney'

# %%
df_india_australia.shape[0] # Total Number of matches palyed between India and Australia
# Out:
# 128

# %%
df_india_australia
# Out:
#        Scorecard     Team 1     Team 2     Winner     Margin     Ground  \
# 96      ODI # 97  Australia      India      India    66 runs  Melbourne
# 99     ODI # 100  Australia      India  Australia  9 wickets     Sydney
# 103    ODI # 104  Australia      India  Australia  9 wickets     Sydney
# 105    ODI # 106  Australia      India  Australia  7 wickets  Melbourne
# 107    ODI # 108  Australia      India  Australia    27 runs     Sydney
# ...          ...        ...        ...        ...        ...        ...
# 3909  ODI # 3910      India  Australia      India    26 runs    Chennai
# 3911  ODI # 3912      India  Australia      India    50 runs    Kolkata
# 3913  ODI # 3914      India  Australia      India  5 wickets     Indore
# 3916  ODI # 3917      India  Australia  Australia    21 runs  Bengaluru
# 3918  ODI # 3919      India  Australia      India  7 wickets     Nagpur
#
#         Match Date
# 96     Dec 6, 1980
# 99    Dec 18, 1980
# 103    Jan 8, 1981
# 105   Jan 11, 1981
# 107   Jan 15, 1981
# ...            ...
# 3909  Sep 17, 2017
# 3911  Sep 21, 2017
# 3913  Sep 24, 2017
# 3916  Sep 28, 2017
# 3918   Oct 1, 2017
#
# [128 rows x 7 columns]

# %% [markdown]
# WEST INDIES DOMINANCE
#
# ### BETWEEN THE YEAR 1971 TO 1990

# %%
df_west_indies = df[(df['Team 1'].str.contains('West Indies') | df['Team 2'].str.contains('West Indies'))]

# %%
df_west_indies
# Out:
#        Scorecard     Team 1       Team 2       Winner     Margin       Ground  \
# 7        ODI # 8    England  West Indies      England   1 wicket        Leeds
# 8        ODI # 9    England  West Indies  West Indies  8 wickets     The Oval
# 21      ODI # 22  Sri Lanka  West Indies  West Indies  9 wickets   Manchester
# 25      ODI # 26   Pakistan  West Indies  West Indies   1 wicket   Birmingham
# 28      ODI # 29  Australia  West Indies  West Indies  7 wickets     The Oval
# ...          ...        ...          ...          ...        ...          ...
# 3910  ODI # 3911    England  West Indies      England  7 wickets   Manchester
# 3912  ODI # 3913    England  West Indies    no result        NaN   Nottingham
# 3914  ODI # 3915    England  West Indies      England   124 runs      Bristol
# 3915  ODI # 3916    England  West Indies      England     6 runs     The Oval
# 3917  ODI # 3918    England  West Indies      England  9 wickets  Southampton
#
#         Match Date
# 7      Sep 5, 1973
# 8      Sep 7, 1973
# 21     Jun 7, 1975
# 25    Jun 11, 1975
# 28    Jun 14, 1975
# ...            ...
# 3910  Sep 19, 2017
# 3912  Sep 21, 2017
# 3914  Sep 24, 2017
# 3915  Sep 27, 2017
# 3917  Sep 29, 2017
#
# [767 rows x 7 columns]

# %%
total_number_of_matches = df_west_indies.shape
total = total_number_of_matches[0]
total
# Out:
# 767

# %%
most_matches_won = df_west_indies['Winner'].value_counts(sort=True).keys()[0]
most_matches_won
# Out:
# 'West Indies'

# %%
total_won_number = df_west_indies['Winner'].value_counts(sort=True)[0]
total_won_number
# Out:
# 380

# %%
win_ratio = int(total_won_number) / int(total)
final_win_ratio = win_ratio * 100
final_win_ratio
# Out:
# 49.54367666232073
